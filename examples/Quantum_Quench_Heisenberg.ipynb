# %%
import sys
sys.path.append('/Users/lindsaybassman/Documents/LBL/ArQTiC')
from arqtic.simulation_generator import Simulation_Generator

# %%
#create simulation object
sim_obj = Simulation_Generator("quench_Heisenberg.txt")
#First time user of IBM's Quantum Experience API? Run the line below
#sim_obj.connect_IBM(api_key="your_key_here")
#If you already run IBM Quantum Experience API jobs, run the following instead:
sim_obj.connect_IBM()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
sim_obj.generate_programs()
sim_obj.run_circuits()
results=sim_obj.result_matrix
results02 = results

#sim_obj.Jz = 0.0
#sim_obj.generate_programs()
#sim_obj.run_circuits()
#results=sim_obj.result_matrix
#results0 = results

#sim_obj.Jz = -4.0
#sim_obj.generate_programs()
#sim_obj.run_circuits()
#results=sim_obj.result_matrix
#results4 = results
# Out:
# Generating timestep 0 program
# Generating timestep 1 program
# Generating timestep 2 program
# Generating timestep 3 program
# Generating timestep 4 program
# Generating timestep 5 program
# Generating timestep 6 program
# Generating timestep 7 program
# Generating timestep 8 program
# Generating timestep 9 program
# Generating timestep 10 program
# Creating IBM quantum circuit objects...
# IBM quantum circuit objects created
# Transpiling circuits...
# Circuits transpiled successfully
# Running noiseless simulator job...
# Noiseless simulator job successful

# %%
(sim_obj.programs_list[1].print_list())
# Out:
# H [0]
# H [1]
# CNOT [0, 1]
# RZ ( 0.07596336742569264 ) [1]
# CNOT [0, 1]
# H [0]
# H [1]
# H [1]
# H [2]
# CNOT [1, 2]
# RZ ( 0.07596336742569264 ) [2]
# CNOT [1, 2]
# H [1]
# H [2]
# H [2]
# H [3]
# CNOT [2, 3]
# RZ ( 0.07596336742569264 ) [3]
# CNOT [2, 3]
# H [2]
# H [3]
# H [3]
# H [4]
# CNOT [3, 4]
# RZ ( 0.07596336742569264 ) [4]
# CNOT [3, 4]
# H [3]
# H [4]
# H [4]
# H [5]
# CNOT [4, 5]
# RZ ( 0.07596336742569264 ) [5]
# CNOT [4, 5]
# H [4]
# H [5]
# H [5]
# H [6]
# CNOT [5, 6]
# RZ ( 0.07596336742569264 ) [6]
# CNOT [5, 6]
# H [5]
# H [6]
# RX ( -1.5707963267948966 ) [0]
# RX ( -1.5707963267948966 ) [1]
# CNOT [0, 1]
# RZ ( 0.07596336742569264 ) [1]
# CNOT [0, 1]
# RX ( 1.5707963267948966 ) [0]
# RX ( 1.5707963267948966 ) [1]
# RX ( -1.5707963267948966 ) [1]
# RX ( -1.5707963267948966 ) [2]
# CNOT [1, 2]
# RZ ( 0.07596336742569264 ) [2]
# CNOT [1, 2]
# RX ( 1.5707963267948966 ) [1]
# RX ( 1.5707963267948966 ) [2]
# RX ( -1.5707963267948966 ) [2]
# RX ( -1.5707963267948966 ) [3]
# CNOT [2, 3]
# RZ ( 0.07596336742569264 ) [3]
# CNOT [2, 3]
# RX ( 1.5707963267948966 ) [2]
# RX ( 1.5707963267948966 ) [3]
# RX ( -1.5707963267948966 ) [3]
# RX ( -1.5707963267948966 ) [4]
# CNOT [3, 4]
# RZ ( 0.07596336742569264 ) [4]
# CNOT [3, 4]
# RX ( 1.5707963267948966 ) [3]
# RX ( 1.5707963267948966 ) [4]
# RX ( -1.5707963267948966 ) [4]
# RX ( -1.5707963267948966 ) [5]
# CNOT [4, 5]
# RZ ( 0.07596336742569264 ) [5]
# CNOT [4, 5]
# RX ( 1.5707963267948966 ) [4]
# RX ( 1.5707963267948966 ) [5]
# RX ( -1.5707963267948966 ) [5]
# RX ( -1.5707963267948966 ) [6]
# CNOT [5, 6]
# RZ ( 0.07596336742569264 ) [6]
# CNOT [5, 6]
# RX ( 1.5707963267948966 ) [5]
# RX ( 1.5707963267948966 ) [6]
# CNOT [0, 1]
# RZ ( 0.015192673485138529 ) [1]
# CNOT [0, 1]
# CNOT [1, 2]
# RZ ( 0.015192673485138529 ) [2]
# CNOT [1, 2]
# CNOT [2, 3]
# RZ ( 0.015192673485138529 ) [3]
# CNOT [2, 3]
# CNOT [3, 4]
# RZ ( 0.015192673485138529 ) [4]
# CNOT [3, 4]
# CNOT [4, 5]
# RZ ( 0.015192673485138529 ) [5]
# CNOT [4, 5]
# CNOT [5, 6]
# RZ ( 0.015192673485138529 ) [6]
# CNOT [5, 6]

# %%
import numpy as np
plt.figure(figsize=(6,4))
plt.plot(results0a, label="$g = 0$")
#plt.plot(results01, label="$\Delta = 0.1$")
plt.plot(results02a, label="$g = 0.2$")
#plt.plot(results1, label="$\Delta = 1.0$")
#plt.plot(results2, label="$\Delta = 2.0$")
plt.plot(results4a, label="$g = 4.0$")
plt.hlines(0, 0, 150, linestyles='dashed')
plt.ylim(-0.6,1.0)
plt.xlim(0,100)
#plt.legend()
plt.xlabel("Simulation Timestep", fontsize=12, fontname="Times New Roman")
plt.yticks([-0.5, -0.25, 0.0, 0.25, 0.5, 0.75, 1.0], fontsize=12, fontname="Times New Roman")
plt.xticks(fontsize=12, fontname="Times New Roman")
plt.ylabel("Staggered Magnetization", fontsize=12, fontname="Times New Roman")
#plt.show()
plt.savefig("staggered_mag_0_0.2_4.0_dt0.025_no_legend.png")
