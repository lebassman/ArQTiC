# %%
import sys
sys.path.append('/Users/lindsaybassman/Documents/LBL/ArQTiC')
from arqtic.simulation_generator import Simulation_Generator
import numpy as np

# %%
#create simulation object
sim_obj = Simulation_Generator("transverse_XY_input.txt")

# %%
#connect to IBM
#if this is your first run enter your API key
#sim_obj.connect_IBM(api_key="your_key_here")
sim_obj.connect_IBM()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '

# %%
sim_obj.generate_circuits()
# Out:
# Generating timestep 0 program
# Generating timestep 1 program
# Generating timestep 2 program
# Generating timestep 3 program
# Generating timestep 4 program
# Generating timestep 5 program
# Generating timestep 6 program
# Generating timestep 7 program
# Generating timestep 8 program
# Generating timestep 9 program
# Generating timestep 10 program
# Generating timestep 11 program
# Generating timestep 12 program
# Generating timestep 13 program
# Generating timestep 14 program
# Generating timestep 15 program
# Generating timestep 16 program
# Generating timestep 17 program
# Generating timestep 18 program
# Generating timestep 19 program
# Generating timestep 20 program
# Creating IBM quantum circuit objects...
# IBM quantum circuit objects created
# Transpiling circuits...
# Circuits transpiled successfully

# %%
#run circuits on backend
sim_obj.run_circuits()
# Out:
# Running noiseless simulator job...
# Noiseless simulator job successful
# {'00001': 1024}
# {'00001': 791, '10011': 3, '10101': 7, '10110': 1, '11001': 1, '00010': 188, '00100': 21, '01011': 11, '01101': 1}
# {'00001': 622, '10011': 5, '10101': 7, '10110': 1, '00010': 264, '00100': 87, '01000': 15, '01011': 10, '01101': 12, '01110': 1}
# {'00001': 725, '10000': 8, '10101': 17, '10110': 4, '11100': 2, '00010': 59, '00100': 106, '00111': 1, '01000': 87, '01011': 3, '01101': 12}
# {'00001': 671, '10000': 40, '10011': 10, '10101': 10, '11001': 3, '11010': 1, '11100': 1, '00010': 134, '00100': 13, '01000': 124, '01011': 14, '01101': 2, '01110': 1}
# {'00001': 607, '10000': 101, '10011': 1, '10101': 5, '00010': 153, '00100': 29, '01000': 107, '01011': 19, '01101': 2}
# {'00001': 720, '10000': 40, '10101': 16, '11001': 3, '11100': 1, '00010': 10, '00100': 89, '00111': 1, '01000': 140, '01101': 4}
# {'00001': 517, '10000': 2, '10011': 1, '10101': 8, '11001': 2, '11010': 1, '11100': 3, '00010': 192, '00100': 102, '00111': 2, '01000': 177, '01011': 13, '01101': 3, '01110': 1}
# {'00001': 340, '10000': 61, '10011': 3, '10101': 5, '11001': 5, '11010': 1, '00010': 271, '00100': 236, '00111': 1, '01000': 79, '01011': 11, '01101': 11}
# {'00001': 411, '10000': 64, '10011': 3, '10101': 5, '10110': 3, '11001': 5, '00010': 73, '00100': 283, '00111': 1, '01000': 153, '01011': 7, '01101': 16}
# {'00001': 434, '10000': 8, '10011': 3, '10101': 2, '10110': 2, '11001': 5, '11010': 1, '00010': 95, '00100': 67, '01000': 397, '01011': 5, '01101': 5}
# {'00001': 419, '10000': 82, '10101': 3, '10110': 1, '11001': 5, '11010': 1, '11100': 8, '00010': 81, '00100': 38, '01000': 376, '01011': 3, '01101': 6, '01110': 1}
# {'00001': 427, '10000': 169, '10011': 1, '10101': 17, '11001': 6, '11100': 2, '00010': 37, '00100': 165, '01000': 175, '01011': 6, '01101': 19}
# {'00001': 289, '10000': 57, '10011': 4, '10101': 7, '10110': 5, '11001': 9, '11100': 1, '00010': 231, '00100': 139, '01000': 248, '01011': 19, '01101': 15}
# {'00001': 333, '10000': 7, '10011': 1, '10101': 6, '10110': 3, '11001': 7, '11010': 1, '11100': 2, '00010': 186, '00100': 193, '00111': 2, '01000': 241, '01011': 14, '01101': 26, '01110': 2}
# {'00001': 458, '10000': 103, '10011': 1, '10101': 23, '11001': 1, '00010': 45, '00100': 252, '01000': 121, '01011': 5, '01101': 15}
# {'00001': 443, '10000': 93, '10011': 1, '10101': 6, '10110': 2, '00010': 144, '00100': 104, '01000': 219, '01011': 5, '01101': 7}
# {'00001': 570, '10000': 17, '10011': 1, '10101': 2, '10110': 1, '11100': 1, '00010': 61, '00100': 13, '01000': 357, '01011': 1}
# {'00001': 596, '10000': 22, '10101': 6, '10110': 1, '11100': 7, '11111': 1, '00010': 68, '00100': 125, '01000': 185, '01011': 6, '01101': 7}
# {'00001': 419, '10000': 42, '10011': 10, '10101': 7, '10110': 1, '11001': 8, '00010': 322, '00100': 94, '01000': 81, '01011': 31, '01101': 7, '01110': 2}
# {'00001': 590, '10000': 15, '10011': 1, '10101': 23, '10110': 9, '11001': 8, '11010': 1, '00010': 230, '00100': 76, '00111': 1, '01000': 51, '01011': 16, '01101': 3}
# [0.0, 0.341796875, 0.6474609375, 0.7685546875, 0.890625, 1.0322265625, 0.8955078125, 1.08984375, 1.380859375, 1.529296875, 1.5439453125, 1.7587890625, 1.810546875, 1.7587890625, 1.625, 1.5322265625, 1.4560546875, 1.2333984375, 1.109375, 1.2177734375, 0.9248046875]

# %%
results=sim_obj.result_matrix
import matplotlib.pyplot as plt
plt.plot(results)
#plt.ylim(-1,1)
#plt.xlim(0,sim_obj.steps)

plt.xlabel("Simulation Timestep")
plt.ylabel("Excitation Displacement")
plt.show()

# %%
results=sim_obj.result_matrix
import matplotlib.pyplot as plt
plt.plot(results)
#plt.ylim(-1,1)
#plt.xlim(0,sim_obj.steps)

plt.xlabel("Simulation Timestep")
plt.ylabel("Excitation Displacement")
plt.show()
